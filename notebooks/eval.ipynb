# %% [markdown]
# # RAG Evaluation Notebook
#
# Evaluación cualitativa y cuantitativa del pipeline.
#
# **TODO (v0.3):**
# - Definir 20-30 pares Q&A ground-truth
# - Medir hit@k para el retriever
# - Evaluar faithfulness de las respuestas
# - Comparar configuraciones: chunk_size × k × modelo_embedding

# %%
# Placeholder — se completa en v0.3
print('Eval notebook - coming in v0.3')
